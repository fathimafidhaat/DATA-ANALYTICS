# %% [markdown]
# # JSON FILE

# %%
import json
list={"name":"fidha","age":21,"education":"B.com graduated","place":"malappuram","year of passout":2026}
with open("list.json","w")as file:
    json.dump(list,file)
with open("data.json","r")as file:
    print(json.load(file))
# Out:
# {'name': 'fidha', 'age': 21, 'education': 'B.com graduated', 'place': 'malappuram', 'year of passout': 2026}
