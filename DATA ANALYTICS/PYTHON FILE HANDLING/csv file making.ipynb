# %% [markdown]
# # CSV FILE

# %%
import csv

with open("studentdata.csv","w",newline="")as file:
    text=csv.writer(file)
    text.writerow(["NAME","AGE","CLASS","DIVISION","PRESENT DAYS","NO.OF WORKING DAYS","PERCENTAGE","SECOND LANGUAGE","MEDIUM","TUTOR"])
    text.writerow(["FIDHA",16,10,"A",45,50,94,"MALAYALAM","EM","SISLY"])
    text.writerow(["JALVA",16,10,"A",46,50,95,"ARABIC","EM","SISLY"])
    text.writerow(["MUFEEDA",15,9,"C",50,50,100,"MALAYALAM","MM","LILLY"])
    text.writerow(["SHIBNA",13,7,"B",47,50,96,"ARABIC","EM","FIDHA"])
    text.writerow(["YUSRA",16,10,"C",45,50,95,"MALAYALAM","MM","GHEETHA"])
    text.writerow(["ARAVIND",15,9,"A",47,50,96,"SAMSKRITH","EM","AKHIL"])
    text.writerow(["ARSHAD",16,10,"A",45,50,95,"MALAYALAM","EM","MERRY"])
    text.writerow(["AMEEN",15,9,"D",44,50,92,"URUDU","MM","GEORGE"])
    text.writerow(["ANANDHU",14,8,"B",45,50,95,"MALAYALAM","EM","ANNA"])
    text.writerow(["NIRANJAN",15,9,"A",50,50,100,"MALAYALAM","EM","SISLY"])
