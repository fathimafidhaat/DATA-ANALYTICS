# %% [markdown]
# # PYTHON VARIABLE TASKS

# %%
#1. Create a variable name and store your name in it. Print the variable.
name="fidha"
print(name)
# Out:
# fidha

# %%
#2. Create variables to store your age , height , and city . Print all three values.
age=21
height=165
city="malappuram"
print("age:",age,"height:",height,"city:",city)
# Out:
# age: 21 height: 165 city: malappuram

# %%
#3. Create two variables a and b with values 25 and 15 . Print their values.
a=25
b=15
print(a,b)
# Out:
# 25 15

# %%
#4. Create three variables to store the marks of English, Maths, and Science. Print the marks.
english=50
maths=45
science=43
print("english:",english)
print("maths:",maths)
print("science:",science)
# Out:
# english: 50
# maths: 45
# science: 43

# %%
#5. Create a variable price and store 500 in it. Update the value to 750 and print it.
price=500
price=750
print(price)
# Out:
# 750

# %%
#6. Create a variable score with the value 80 . Increase its value by 10 and print the result.
score=80
score+=10
print(score)
# Out:
# 90

# %%
#7. Create two variables a = 10 and b = 20 . Swap their values and print the result.
a=10
b=20
a,b=b,a
print("a:",a)
print("b:",b)
# Out:
# a: 20
# b: 10

# %%
#8. Create variables for a product name, price, and quantity. Display all the values.
product="cake"
price=250
qty=2
print("product:",product)
print("price:",price)
print("qty:",qty)
# Out:
# product: cake
# price: 250
# qty: 2

# %%
#9. Create variables length = 20 and width = 10 . Calculate and store the area of the rectangle in another variable and print it.
length = 20
width = 10
area=length*width
print("area of rectangle:",area)
# Out:
# area of rectangle: 200

# %%
#10. Create variables for three subject marks and store their total in a variable called total .
sub1=80
sub2=90
sub3=85
total=sub1+sub2+sub3
print("total:",total)
# Out:
# total: 255

# %%
#11. Create variables principal , rate , and time . Calculate simple interest and store the result in a variable.
principal=2000
rate=4
time=5
simple_intrest=(principal*rate*time)/100
print("simple intrest:",simple_intrest)
# Out:
# simple intrest: 400.0

# %%
#12. Create a variable num and store a number in it. Create another variable to store its square.
num=5
sqr=num**2
print("square:",sqr)
# Out:
# square: 25

# %%
#13. Create a variable num and store a number in it. Create another variable to store its cube.
num=6
cube=num**3
print("cube:",cube)
# Out:
# cube: 216

# %%
#14. Create two variables containing numbers and store their sum, difference, product, and division in separate variables.
a=10
b=5
sum=a+b
difference=a-b
product=a*b
division=a/b
print("sum:",sum)
print("difference:",difference)
print("product:",product)
print("division:",division)
# Out:
# sum: 15
# difference: 5
# product: 50
# division: 2.0

# %%
#15. Create variables to store a student's name, roll number, course, and marks. Display all the details.
name="fidha"
roll_no=43
course="data_analytics"
mark=80
print("name:",name)
print("roll number:",roll_no)
print("course:",course)
print("marks:",mark)
# Out:
# name: fidha
# roll number: 43
# course: data_analytics
# marks: 80
