# %% [markdown]
# # PYTHON MATCH

# %%
#Display the full form of department code.....
a=str(input("enter department code:(CS/IT/EC/ME)")).upper()
match a:
    case "CS":
        print("Computer Science")
    case "IT":
        print("Information Technology")
    case "EC":
        print("Electronics")
    case "ME":
        print("Mechanical") 
    case _:
        print("no course")
# Out:
# enter department code:(CS/IT/EC/ME) cs
# Computer Science

# %%
#display the month name based on a month number(1-12)
month=int(input("enter a month number:"))
match month:
    case 1:
        print("JANUARY")
    case 2:
        print("FEBRUARY")
    case 3:
        print("MARCH")
    case 4:
        print("APRIL")
    case 5:
        print("MAY")
    case 6:
        print("JUNE")
    case 7:
        print("JULY")
    case 8:
        print("AUGUST")
    case 9:
        print("SEPTEMBER")
    case 10:
        print("OCTOBER")
    case 11:
        print("NOVEMBER")
    case 12:
        print("DECEMBER")
    case _:
        print("INVALID")
# Out:
# enter a month number: 6
# JUNE

# %%
#create a simple calculator using match(+,,,/)
num1=int(input("enter a number:"))
operator=(input("enter the operator:(+,-,*</)"))
num2=int(input("enter a number:"))
match operator:
    case "+":
        print(num1+num2)
    case "-":
        print(num1-num2)
    case "*":
        print(num1*num2)
    case "/":
        if num2 !=0:
            print("possible division")
            print(num1/num2)
        else:
            print("division is not possible")
    case _:
        print("invalid")
# Out:
# enter a number: 8
# enter the operator:(+,-,*</) /
# enter a number: 0
# division is not possible

# %%
#display the grade description based on a grade(A,B,C,D,F)
grade=str(input("enter grade:(A,B,C,D,F)")).upper()
match grade:
    case "A":
        print("Exellent")
    case "B":
        print("Good")
    case "C":
        print("Average")
    case "D":
        print("Pass")
    case "F":
        print("Fail")
    case _:
        print("invalid")
# Out:
# enter grade:(A,B,C,D,F) b
# Good

# %%
#display the season based on a month number
month=int(input("enter month number:"))
match month:
    case 1|2|12:
        print("WINTER")
    case 3|4|5:
        print("SUMMER")
    case 6|7|8|9:
        print("MONSOON")
    case 10|11:
        print("SPRING")
    case _:
        print("INVALID")
# Out:
# enter month number: 6
# MONSOON

# %%
#display the number of days in a month using the month number
month=int(input("enter month number"))
match month:
    case 1|3|5|7|8|10|12:
        print("31 days")
    case 4|6|9|11:
        print("30 days")
    case 2:
        print("28 days")
    case _:
        print("invalid")
# Out:
# enter month number 2
# 28 days

# %%
#create a menu-driven program to select a drink(tea,coffee,juice,water)
print("---------------  MENU  --------------------")
print("1. Tea")
print("2. Coffee")
print("3. Juice")
print("4. Water")

choice = int(input("enter the choice (1-4):"))
match choice:
    case 1:
        print("you selected tea")
    case 2:
        print("you selected coffee")
    case 3:
        print("you selected juice")
    case 4:
        print("you selected water")
    case _:
        print("invalid choice")
# Out:
# ---------------  MENU  --------------------
# 1. Tea
# 2. Coffee
# 3. Juice
# 4. Water
# enter the choice (1-4): 2
# you selected coffee

# %%
#display the type of vehicles based on vechicle code(B:bike,C:car,T:truck,S:scooter)
vehicle=str(input("enter vehicle code(B/C/T/S)")).upper()
match vehicle:
    case "B":
        print("BIKE")
    case "C":
        print("CAR")
    case "T":
        print("TRUCK")
    case "S":
        print("SCOOTER")
    case _:
        print("invalid")
# Out:
# enter vehicle code(B/C/T/S) S
# SCOOTER

# %%
#display the result of a students attendance status based on the input (P-present,A-absent,L-leave)
attendance=str(input("enter attendance status(P/A/L)")).upper()
match attendance:
    case "P":
        print("present")
    case "L":
        print("leave")
    case "A":
        print("absent")
    case _:
        print("invalid")
# Out:
# enter attendance status(P/A/L) a
# absent

# %%
#display the name of a programming language based on a code language(P-python,J-java,C-C,R-R)
code=str(input("enter language code(P/J/C/R)")).upper()
match code:
    case "P":
        print("python")
    case "J":
        print("java")
    case "C":
        print("C")
    case "R":
        print("R")
    case _:
        print("invalid")
# Out:
# enter language code(P/J/C/R) j
# java
