# %% [markdown]
# ## 1D ARRAY

# %%
import numpy as np

# %%
a=np.array([10,20,30,40,50,60,0])

# %%
a.dtype
# Out:
# dtype('int64')

# %%
a.shape
# Out:
# (7,)

# %%
a.ndim
# Out:
# 1

# %%
a.size
# Out:
# 7

# %%
a[0]
# Out:
# np.int64(10)

# %%
a[2]
# Out:
# np.int64(30)
